# %% [markdown]
# # 10 minutes to Pandas
# [Pandas](https://pandas.pydata.org/docs/index.html) is one of the most popular tools for data analysis in Python. This open-source library is the backbone of many data projects and is used for data cleaning and data manipulation.
# With Pandas, you gain greater control over complex data sets. It’s an essential tool in the data analysis tool belt. If you’re not using Pandas, you’re not making the most of your data.
#
# In this walkthrough, we're going to take a look at some most used Pandas' operations and commands:
#
# * [Create a DataFrame](#Create-a-DataFrame)
# * [Import Dataset](#Import-Dataset)
# * [Row/Column Selection, Addition, and Deletion](#Row/Column-Selection,-Addition,-and-Deletion)
# * [Slice a DataFrame](#Slice-a-DataFrame)
# * [Group data](#Group-data)

# %% [markdown]
# ---
# First, let's import Pandas and check if it's installed.

# %%
import pandas as pd
pd.__version__
# Out:
# '1.4.1'

# %% [markdown]
# ### Create a DataFrame
# A pandas DataFrame can be created using various inputs like
# 1. [Lists](#1.-Lists)
# 2. [Dict](#2.-Dict)
# 3. [Series](#3.-Series)
# 4. [Numpy Arrays](#4.Numpy-Arrays)
# 5. Another DataFrame

# %% [markdown]
# #### 1. Lists

# %%
data = [1,2,3,4,5]
df = pd.DataFrame(data)
df
# Out:
#    0
# 0  1
# 1  2
# 2  3
# 3  4
# 4  5

# %%
data = [['Alex',10],['Bob',12],['Clarke',13]]
df = pd.DataFrame(data,columns=['Name','Age'])
df
# Out:
#      Name  Age
# 0    Alex   10
# 1     Bob   12
# 2  Clarke   13

# %% [markdown]
# #### 2. Dict
# The dictionary keys are by default taken as column names.

# %%
data = {'Name':['Tom', 'Jack', 'Steve', 'Ricky'],'Age':[28,34,29,42]}
df = pd.DataFrame(data)
df
# Out:
#     Name  Age
# 0    Tom   28
# 1   Jack   34
# 2  Steve   29
# 3  Ricky   42

# %%
data = [{'a': 1, 'b': 2},{'a': 5, 'b': 10, 'c': 20}]
df = pd.DataFrame(data)
df
# Note: NaN (Not a Number) is appended in missing areas.
# Out:
#    a   b     c
# 0  1   2   NaN
# 1  5  10  20.0

# %% [markdown]
# #### 3. Series

# %%
data = {
    'a' : pd.Series([1, 2, 3], index=['a', 'b', 'c']),
    'b' : pd.Series([1, 2, 3, 4], index=['a', 'b', 'c', 'd'])
}

df = pd.DataFrame(data)
df
# Out:
#      a  b
# a  1.0  1
# b  2.0  2
# c  3.0  3
# d  NaN  4

# %% [markdown]
# #### 4.Numpy Arrays

# %%
import numpy as np

# Create a Numpy array
array = np.array([[1, 1, 1], [2, 4, 8], [3, 9, 27], 
                  [4, 16, 64], [5, 25, 125], [6, 36, 216], 
                  [7, 49, 343]])
  
# Create index
index_values = ['first', 'second', 'third',
                'fourth', 'fifth', 'sixth', 'seventh']
   
# Create column names
column_values = ['number', 'squares', 'cubes']
  
# Create the dataframe
df = pd.DataFrame(data = array, 
                  index = index_values, 
                  columns = column_values)
df
# Out:
#          number  squares  cubes
# first         1        1      1
# second        2        4      8
# third         3        9     27
# fourth        4       16     64
# fifth         5       25    125
# sixth         6       36    216
# seventh       7       49    343

# %% [markdown]
# ### Import Dataset

# %%
# Import a CSV file into dataframe
df = pd.read_csv("data/employees_info.csv")
df
# Out:
#                      name gender                   job title  \
# 0    Maximilianus Kertess      M          Biostatistician II
# 1          Hayley Robshaw      F  Administrative Assistant I
# 2         Margaret Anetts      F                Food Chemist
# 3             West Kittoe      M      Nuclear Power Engineer
# 4            Bucky Gillon      M            Dental Hygienist
# ..                    ...    ...                         ...
# 995         Dillon Howatt      M         Clinical Specialist
# 996      Carlyle McKinnon      M               Programmer II
# 997            Des Fayter      M     Assistant Media Planner
# 998          Amberly Gabb      F            Media Manager II
# 999       Leena Glowinski      F              Civil Engineer
#
#                    department         phone                   email  \
# 0    Research and Development  752-802-7785     mkertess0@imgur.com
# 1                   Marketing  540-813-4217     hrobshaw1@weibo.com
# 2                    Services  593-431-7020    manetts2@skyrock.com
# 3                    Services  762-464-6485     wkittoe3@ustream.tv
# 4                       Legal  419-969-8647        bgillon4@home.pl
# ..                        ...           ...                     ...
# 995  Research and Development  464-126-8895    dhowattrn@google.com
# 996        Product Management  327-200-2857     cmckinnonro@mail.ru
# 997                Accounting  133-479-3458        dfayterrp@ca.gov
# 998        Product Management  919-701-1347         agabbrq@nyu.edu
# 999        Product Management  909-270-4772  lglowinskirr@hc360.com
#
#         residence                address            time zone
# 0          Canada      18411 Sugar Point     America/Edmonton
# 1           China    1281 Namekagon Lane       Asia/Chongqing
# 2         Belgium      7404 Dakota Alley      Europe/Brussels
# 3          Poland      92750 Buell Drive        Europe/Warsaw
# 4           China     3068 Morrow Street       Asia/Chongqing
# ..            ...                    ...                  ...
# 995        Mexico          402 Pond Lane  America/Mexico_City
# 996       Croatia          5 Amoth Place        Europe/Zagreb
# 997        Sweden          79 Larry Pass     Europe/Stockholm
# 998      Paraguay  985 Summer Ridge Road     America/Asuncion
# 999  South Africa          51 Stang Pass  Africa/Johannesburg
#
# [1000 rows x 9 columns]

# %%
# Get all column names
df.columns
# Out:
# Index(['name', 'gender', 'job title', 'department', 'phone', 'email',
#        'residence', 'address', 'time zone'],
#       dtype='object')

# %%
# Use head() or tail() to get the first/last five records of the dataframe by default
df.head()
# Out:
#                    name gender                   job title  \
# 0  Maximilianus Kertess      M          Biostatistician II
# 1        Hayley Robshaw      F  Administrative Assistant I
# 2       Margaret Anetts      F                Food Chemist
# 3           West Kittoe      M      Nuclear Power Engineer
# 4          Bucky Gillon      M            Dental Hygienist
#
#                  department         phone                 email residence  \
# 0  Research and Development  752-802-7785   mkertess0@imgur.com    Canada
# 1                 Marketing  540-813-4217   hrobshaw1@weibo.com     China
# 2                  Services  593-431-7020  manetts2@skyrock.com   Belgium
# 3                  Services  762-464-6485   wkittoe3@ustream.tv    Poland
# 4                     Legal  419-969-8647      bgillon4@home.pl     China
#
#                address         time zone
# 0    18411 Sugar Point  America/Edmonton
# 1  1281 Namekagon Lane    Asia/Chongqing
# 2    7404 Dakota Alley   Europe/Brussels
# 3    92750 Buell Drive     Europe/Warsaw
# 4   3068 Morrow Street    Asia/Chongqing

# %%
# or just specify how many records to display by giving a number
df.tail(3)
# Out:
#                 name gender                job title          department  \
# 997       Des Fayter      M  Assistant Media Planner          Accounting
# 998     Amberly Gabb      F         Media Manager II  Product Management
# 999  Leena Glowinski      F           Civil Engineer  Product Management
#
#             phone                   email     residence  \
# 997  133-479-3458        dfayterrp@ca.gov        Sweden
# 998  919-701-1347         agabbrq@nyu.edu      Paraguay
# 999  909-270-4772  lglowinskirr@hc360.com  South Africa
#
#                    address            time zone
# 997          79 Larry Pass     Europe/Stockholm
# 998  985 Summer Ridge Road     America/Asuncion
# 999          51 Stang Pass  Africa/Johannesburg

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        1000 non-null   object
#  1   gender      1000 non-null   object
#  2   job title   1000 non-null   object
#  3   department  1000 non-null   object
#  4   phone       1000 non-null   object
#  5   email       1000 non-null   object
#  6   residence   1000 non-null   object
#  7   address     1000 non-null   object
#  8   time zone   1000 non-null   object
# dtypes: object(9)
# memory usage: 70.4+ KB

# %%
df.describe()
# Out:
#                         name gender  job title department         phone  \
# count                   1000   1000       1000       1000          1000
# unique                  1000      2        183         12          1000
# top     Maximilianus Kertess      M  Recruiter  Marketing  752-802-7785
# freq                       1    509         20         98             1
#
#                       email residence            address       time zone
# count                  1000      1000               1000            1000
# unique                 1000       124               1000             162
# top     mkertess0@imgur.com     China  18411 Sugar Point  Asia/Chongqing
# freq                      1       175                  1              82

# %% [markdown]
# ### Row/Column Selection, Addition, and Deletion

# %%
# Create a test dataframe
data = {'Name':['Tom', 'Jack', 'Steve', 'Ricky'],'Age':[28,34,29,42]}
df = pd.DataFrame(data)
df
# Out:
#     Name  Age
# 0    Tom   28
# 1   Jack   34
# 2  Steve   29
# 3  Ricky   42

# %%
# Select a column
df['Name']
# Out:
# 0      Tom
# 1     Jack
# 2    Steve
# 3    Ricky
# Name: Name, dtype: object

# %%
# Select a row
df.loc[0]
# Out:
# Name    Tom
# Age      28
# Name: 0, dtype: object

# %%
# Select a cell by giving the column name and index
df.loc[0]['Name']
# Out:
# 'Tom'

# %%
# Add a column
gender = ['M','M','M','F']
df['Gender'] = pd.DataFrame(gender)
df
# Out:
#     Name  Age Gender
# 0    Tom   28      M
# 1   Jack   34      M
# 2  Steve   29      M
# 3  Ricky   42      F

# %%
# Delete a column
del df['Age']
df
# Out:
#     Name Gender
# 0    Tom      M
# 1   Jack      M
# 2  Steve      M
# 3  Ricky      F

# %% [markdown]
# ### Slice a DataFrame
# Sometimes getting a simple Series doesn’t accomplish our goals. For more complex operations, Pandas provides DataFrame Slicing using “loc” and “iloc” functions.
# Multiple rows can be selected using ‘ : ’ operator.

# %%
# Let's use the csv data we just imported
df = pd.read_csv("data/employees_info.csv")
df
# Out:
#                      name gender                   job title  \
# 0    Maximilianus Kertess      M          Biostatistician II
# 1          Hayley Robshaw      F  Administrative Assistant I
# 2         Margaret Anetts      F                Food Chemist
# 3             West Kittoe      M      Nuclear Power Engineer
# 4            Bucky Gillon      M            Dental Hygienist
# ..                    ...    ...                         ...
# 995         Dillon Howatt      M         Clinical Specialist
# 996      Carlyle McKinnon      M               Programmer II
# 997            Des Fayter      M     Assistant Media Planner
# 998          Amberly Gabb      F            Media Manager II
# 999       Leena Glowinski      F              Civil Engineer
#
#                    department         phone                   email  \
# 0    Research and Development  752-802-7785     mkertess0@imgur.com
# 1                   Marketing  540-813-4217     hrobshaw1@weibo.com
# 2                    Services  593-431-7020    manetts2@skyrock.com
# 3                    Services  762-464-6485     wkittoe3@ustream.tv
# 4                       Legal  419-969-8647        bgillon4@home.pl
# ..                        ...           ...                     ...
# 995  Research and Development  464-126-8895    dhowattrn@google.com
# 996        Product Management  327-200-2857     cmckinnonro@mail.ru
# 997                Accounting  133-479-3458        dfayterrp@ca.gov
# 998        Product Management  919-701-1347         agabbrq@nyu.edu
# 999        Product Management  909-270-4772  lglowinskirr@hc360.com
#
#         residence                address            time zone
# 0          Canada      18411 Sugar Point     America/Edmonton
# 1           China    1281 Namekagon Lane       Asia/Chongqing
# 2         Belgium      7404 Dakota Alley      Europe/Brussels
# 3          Poland      92750 Buell Drive        Europe/Warsaw
# 4           China     3068 Morrow Street       Asia/Chongqing
# ..            ...                    ...                  ...
# 995        Mexico          402 Pond Lane  America/Mexico_City
# 996       Croatia          5 Amoth Place        Europe/Zagreb
# 997        Sweden          79 Larry Pass     Europe/Stockholm
# 998      Paraguay  985 Summer Ridge Road     America/Asuncion
# 999  South Africa          51 Stang Pass  Africa/Johannesburg
#
# [1000 rows x 9 columns]

# %%
# Get multiple by giving a range of index
df[1:5]
# Out:
#               name gender                   job title department  \
# 1   Hayley Robshaw      F  Administrative Assistant I  Marketing
# 2  Margaret Anetts      F                Food Chemist   Services
# 3      West Kittoe      M      Nuclear Power Engineer   Services
# 4     Bucky Gillon      M            Dental Hygienist      Legal
#
#           phone                 email residence              address  \
# 1  540-813-4217   hrobshaw1@weibo.com     China  1281 Namekagon Lane
# 2  593-431-7020  manetts2@skyrock.com   Belgium    7404 Dakota Alley
# 3  762-464-6485   wkittoe3@ustream.tv    Poland    92750 Buell Drive
# 4  419-969-8647      bgillon4@home.pl     China   3068 Morrow Street
#
#          time zone
# 1   Asia/Chongqing
# 2  Europe/Brussels
# 3    Europe/Warsaw
# 4   Asia/Chongqing

# %%
# df.loc[<ROWS_TO_SELECT>, <COLUMNS_TO_SELECT>]
df.loc[:,["name","job title"]]
# Out:
#                      name                   job title
# 0    Maximilianus Kertess          Biostatistician II
# 1          Hayley Robshaw  Administrative Assistant I
# 2         Margaret Anetts                Food Chemist
# 3             West Kittoe      Nuclear Power Engineer
# 4            Bucky Gillon            Dental Hygienist
# ..                    ...                         ...
# 995         Dillon Howatt         Clinical Specialist
# 996      Carlyle McKinnon               Programmer II
# 997            Des Fayter     Assistant Media Planner
# 998          Amberly Gabb            Media Manager II
# 999       Leena Glowinski              Civil Engineer
#
# [1000 rows x 2 columns]

# %%
'''
or we can even get the rows on a certain condition. For example, we want to get all the employees that work at
the Accounting department, and we only want to select 'name', 'job title' and 'department' these three columns
'''
accounting_employees = df.loc[(df["department"] == "Accounting"), ["name","job title", "department"]]
accounting_employees
# Out:
#                    name                             job title  department
# 10    Ann-marie Daveley                      Quality Engineer  Accounting
# 18       Willem Tamsett                      Graphic Designer  Accounting
# 34      Jaynell Baselli           Mechanical Systems Engineer  Accounting
# 43         Gale Workman  Business Systems Development Analyst  Accounting
# 68    Ingemar O' Dooley              Senior Financial Analyst  Accounting
# ..                  ...                                   ...         ...
# 937   Jessalyn Domerque                         Senior Editor  Accounting
# 943  Eberhard Josselson                   Account Coordinator  Accounting
# 945         Egor Pittam                    Analyst Programmer  Accounting
# 960    Michelina Gimert                 Safety Technician III  Accounting
# 997          Des Fayter               Assistant Media Planner  Accounting
#
# [91 rows x 3 columns]

# %% [markdown]
# ### Group data

# %%
grouped = df.groupby(["department","name"]).first()
grouped
# Out:
#                              gender                     job title  \
# department name
# Accounting Abie Hawkings          M           Office Assistant II
#            Aleece Gosland         F                        Editor
#            Ambrosius Dun          M                Civil Engineer
#            Andree McGenn          F        Administrative Officer
#            Ann-marie Daveley      F              Quality Engineer
# ...                             ...                           ...
# Training   Vick Shovelbottom      M                      VP Sales
#            Webb Finicj            M    Quality Control Specialist
#            Win Gronav             M  Structural Analysis Engineer
#            Witty Weekley          M          Office Assistant III
#            Yvonne Buret           F            Speech Pathologist
#
#                                      phone                         email  \
# department name
# Accounting Abie Hawkings      247-553-0319     ahawkings3v@woothemes.com
#            Aleece Gosland     924-906-4001         agoslandmm@nature.com
#            Ambrosius Dun      263-465-6885              adunaq@diigo.com
#            Andree McGenn      124-944-2608           amcgenncc@opera.com
#            Ann-marie Daveley  804-815-7609       adaveleya@delicious.com
# ...                                    ...                           ...
# Training   Vick Shovelbottom  518-654-2238  vshovelbottomcn@springer.com
#            Webb Finicj        567-227-4839             wfinicjbo@mail.ru
#            Win Gronav         951-279-9818     wgronavg3@nydailynews.com
#            Witty Weekley      113-252-8572           wweekleyhz@jugem.jp
#            Yvonne Buret       214-450-5098        yburetec@newyorker.com
#
#                                 residence                     address  \
# department name
# Accounting Abie Hawkings          Lebanon          07 Loeprich Center
#            Aleece Gosland          Brazil             19 Merrick Park
#            Ambrosius Dun            Yemen              91 Jenna Alley
#            Andree McGenn          Germany  52455 Loftsgordon Crossing
#            Ann-marie Daveley  Philippines      908 Di Loreto Crossing
# ...                                   ...                         ...
# Training   Vick Shovelbottom       Poland         95 Pierstorff Drive
#            Webb Finicj             Brazil              5 Forster Hill
#            Win Gronav           Indonesia                82 Spohn Way
#            Witty Weekley            China        95 Grayhawk Crossing
#            Yvonne Buret       Philippines             9 Canary Avenue
#
#                                       time zone
# department name
# Accounting Abie Hawkings            Asia/Beirut
#            Aleece Gosland     America/Sao_Paulo
#            Ambrosius Dun              Asia/Aden
#            Andree McGenn          Europe/Berlin
#            Ann-marie Daveley        Asia/Manila
# ...                                         ...
# Training   Vick Shovelbottom      Europe/Warsaw
#            Webb Finicj        America/Fortaleza
#            Win Gronav              Asia/Jakarta
#            Witty Weekley         Asia/Chongqing
#            Yvonne Buret             Asia/Manila
#
# [1000 rows x 7 columns]
